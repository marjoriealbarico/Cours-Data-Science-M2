# %% [markdown]
# # Pandas for Data Science
# This notebook demonstrates powerful capabilities of the Pandas library using a complex dataset.

# %%
import pandas as pd
import numpy as np

# load employee data
employee_data = pd.read_csv('employee_data.csv')
# Display the first few rows of the dataset
employee_data.head()
# Out:
#    EmployeeID   Name Department Team    JoinDate  Age  Salary  \
# 0           1  Emp_1    Finance    D  2019-03-22   29   80704
# 1           2  Emp_2      Sales    A  2020-06-24   48   51561
# 2           3  Emp_3         HR    C  2020-01-29   44   82741
# 3           4  Emp_4         HR    E  2019-01-09   36   33041
# 4           5  Emp_5         HR    B  2019-05-26   53   87055
#
#    PerformanceScore
# 0              3.83
# 1              2.32
# 2              3.78
# 3              2.99
# 4              3.76

# %% [markdown]
# ### GroupBy and Multi-Level Aggregation

# %%
# df is duplicate of employee_data
df = employee_data.copy()

# Average salary and performance by Department and Team
agg_df = df.groupby(['Department', 'Team']).agg({
    'Salary': ['mean', 'max', 'min'],
    'PerformanceScore': ['mean', 'std'],
    'Age': 'median'
})
agg_df
# Out:
#                              Salary                PerformanceScore            \
#                                mean     max    min             mean       std
# Department       Team
# Finance          A     69902.476190  115022  31337         2.871667  0.425268
#                  B     77782.512821  119344  34715         3.064103  0.380289
#                  C     71757.066667  115145  30102         3.013000  0.382209
#                  D     73366.250000  119763  32626         3.069167  0.489941
#                  E     73782.156250  117770  31452         3.116563  0.539693
# HR               A     72177.139535  118432  30013         2.926279  0.493578
#                  B     69841.146341  118302  31345         2.938537  0.593345
#                  C     78227.276596  116458  31288         3.030000  0.525568
#                  D     77782.512821  119558  31537         2.874872  0.543623
#                  E     81830.254902  119903  31107         3.073529  0.473362
# R&D Data Science A     79346.297297  118885  32889         3.052973  0.494233
#                  B     75588.666667  119698  30095         2.929167  0.574299
#                  C     77783.702703  116949  31684         2.921081  0.519170
#                  D     81916.340000  117247  31532         2.918800  0.498228
#                  E     74778.972973  117541  31548         2.911892  0.502609
# R&D Hardware     A     74350.531250  119381  30171         3.014063  0.610499
#                  B     74359.531915  119976  30344         3.034255  0.513719
#                  C     72746.108696  117754  32822         3.133043  0.445301
#                  D     72262.977273  115446  30656         2.999773  0.438647
#                  E     82352.304348  116335  35637         2.982174  0.487880
# Sales            A     77319.342105  115826  32205         3.000263  0.442740
#                  B     81986.090909  117520  35171         3.095758  0.559325
#                  C     79167.921053  119752  30104         2.930526  0.510574
#                  D     77508.954545  119733  30490         2.927273  0.483300
#                  E     74552.652174  115191  30211         2.850435  0.478093
#
#                          Age
#                       median
# Department       Team
# Finance          A      33.5
#                  B      38.0
#                  C      40.5
#                  D      39.0
#                  E      39.5
# HR               A      42.0
#                  B      40.0
#                  C      42.0
#                  D      46.0
#                  E      36.0
# R&D Data Science A      42.0
#                  B      38.0
#                  C      42.0
#                  D      39.5
#                  E      42.0
# R&D Hardware     A      42.5
#                  B      38.0
#                  C      40.5
#                  D      44.0
#                  E      43.0
# Sales            A      40.0
#                  B      39.0
#                  C      41.0
#                  D      41.0
#                  E      41.0

# %%
df.head()
# Out:
#    EmployeeID   Name Department Team    JoinDate  Age  Salary  \
# 0           1  Emp_1    Finance    D  2019-03-22   29   80704
# 1           2  Emp_2      Sales    A  2020-06-24   48   51561
# 2           3  Emp_3         HR    C  2020-01-29   44   82741
# 3           4  Emp_4         HR    E  2019-01-09   36   33041
# 4           5  Emp_5         HR    B  2019-05-26   53   87055
#
#    PerformanceScore
# 0              3.83
# 1              2.32
# 2              3.78
# 3              2.99
# 4              3.76

# %%
# list of departments
departments
# Out:
# ['Finance', 'Sales', 'HR', 'R&D Data Science', 'R&D Hardware']

# %% [markdown]
# ### Filtering with Complex Conditions

# %%
# Employees in Engineering, older than 40, with high performance
filtered = df[
    (df['Department'] == 'Engineering') & 
    (df['Age'] > 40) & 
    (df['PerformanceScore'] > 3.5)
]
filtered.sort_values(by='PerformanceScore', ascending=False)
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Name, Department, Team, JoinDate, Age, Salary, PerformanceScore]
# Index: []

# %%
# Employees in R&D Data Science, older than 40, with high performance
filtered = df[
    (df['Department'] == 'R&D Data Science') & 
    (df['Age'] > 40) & 
    (df['PerformanceScore'] > 3.5)
]
filtered.sort_values(by='PerformanceScore', ascending=False)
# Out:
#      EmployeeID     Name        Department Team    JoinDate  Age  Salary  \
# 829         830  Emp_830  R&D Data Science    C  2020-11-08   45   45940
# 584         585  Emp_585  R&D Data Science    E  2022-06-09   57  107704
# 998         999  Emp_999  R&D Data Science    C  2020-03-25   55   94599
# 696         697  Emp_697  R&D Data Science    A  2019-05-14   59   51124
# 481         482  Emp_482  R&D Data Science    B  2020-03-15   59  111664
# 930         931  Emp_931  R&D Data Science    C  2019-10-09   49   51684
# 5             6    Emp_6  R&D Data Science    D  2019-08-25   43  102712
# 927         928  Emp_928  R&D Data Science    D  2021-01-13   57  109488
# 48           49   Emp_49  R&D Data Science    A  2019-10-06   50  103225
# 365         366  Emp_366  R&D Data Science    B  2021-11-04   47  102067
# 747         748  Emp_748  R&D Data Science    E  2022-01-18   54   39815
# 200         201  Emp_201  R&D Data Science    E  2022-07-30   54   64864
# 373         374  Emp_374  R&D Data Science    E  2022-01-30   59   63069
# 997         998  Emp_998  R&D Data Science    D  2021-08-25   58   67478
#
#      PerformanceScore
# 829              4.12
# 584              4.00
# 998              3.89
# 696              3.81
# 481              3.79
# 930              3.76
# 5                3.75
# 927              3.69
# 48               3.64
# 365              3.63
# 747              3.61
# 200              3.56
# 373              3.56
# 997              3.51

# %% [markdown]
# ### Using `apply()` with Custom Logic

# %%
# Ensure JoinDate is datetime
df['JoinDate'] = pd.to_datetime(df['JoinDate'])

def experience_level(row):
    years = 2025 - row['JoinDate'].year
    if years < 2:
        return 'Junior'
    elif years < 5:
        return 'Mid'
    else:
        return 'Senior'

df['ExperienceLevel'] = df.apply(experience_level, axis=1)
df[['Name', 'JoinDate', 'ExperienceLevel']].head(10)
# Out:
#      Name   JoinDate ExperienceLevel
# 0   Emp_1 2019-03-22          Senior
# 1   Emp_2 2020-06-24          Senior
# 2   Emp_3 2020-01-29          Senior
# 3   Emp_4 2019-01-09          Senior
# 4   Emp_5 2019-05-26          Senior
# 5   Emp_6 2019-08-25          Senior
# 6   Emp_7 2022-05-29             Mid
# 7   Emp_8 2022-10-06             Mid
# 8   Emp_9 2022-02-21             Mid
# 9  Emp_10 2019-04-12          Senior

# %% [markdown]
# ### Creating Pivot Tables

# %%
pivot = pd.pivot_table(df, 
                         index='Department', 
                         columns='ExperienceLevel', 
                         values='Salary', 
                         aggfunc='mean')
pivot
# Out:
# ExperienceLevel            Mid        Senior
# Department
# Finance           72566.871287  74172.100000
# HR                75052.272727  77431.504505
# R&D Data Science  79589.696970  76716.948980
# R&D Hardware      71347.408163  77681.531915
# Sales             75960.250000  79608.631068

# %% [markdown]
# ### Merging DataFrames

# %%
# Simulate a new DataFrame with bonus info
bonus_df = pd.DataFrame({
    'EmployeeID': np.random.choice(df['EmployeeID'], size=50, replace=False),
    'Bonus': np.random.randint(1000, 10000, size=50)
})

# Merge with main data
df_merged = df.merge(bonus_df, on='EmployeeID', how='left')
df_merged[['Name', 'Department', 'Bonus']].head()
# Out:
#     Name Department   Bonus
# 0  Emp_1    Finance     NaN
# 1  Emp_2      Sales     NaN
# 2  Emp_3         HR  3214.0
# 3  Emp_4         HR     NaN
# 4  Emp_5         HR     NaN

# %% [markdown]
# ###  Time Series: Resampling and Rolling Averages

# %%
# Monthly new joiners
monthly_joins = df.set_index('JoinDate').resample('M')['EmployeeID'].count()
monthly_joins.plot(title='Monthly New Joiners', figsize=(10,4));
# Out:
# /var/folders/cl/6_0whlbd23s869f21tq5xj900000gn/T/ipykernel_5237/2991335424.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_joins = df.set_index('JoinDate').resample('M')['EmployeeID'].count()

# %% [markdown]
# ## Exercice: Sales Data Analysis
#
# You are provided with a dataset `sales_data.csv` containing retail transactions with the following columns:
#
# - `OrderID`: Order identifier
# - `CustomerID`: Unique customer identifier
# - `Product`: Product name
# - `Category`: Product category
# - `Quantity`: Number of units sold
# - `Price`: Unit price
# - `OrderDate`: Date of the order
# - `Country`: Customer's country
#
# ### Tasks:
#
# 1. **Basic Exploration**:
#    - Display the first 5 rows.
#    - Count missing values in each column.
#    - Print summary statistics for `Quantity` and `Price`.
#
# 2. **Data Cleaning**:
#    - Remove rows where `Quantity` or `Price` is less than or equal to 0.
#    - Convert `OrderDate` to datetime format.
#
# 3. **Feature Engineering**:
#    - Create a new column `TotalAmount` = `Quantity` × `Price`.
#    - Extract the `Month` and `DayOfWeek` from `OrderDate`.
#
# 4. **Analysis**:
#    - What is the total revenue per `Country`? (Sort descending)
#    - What are the top 5 best-selling products by `Quantity`?
#    - How many unique customers are there in each `Country`?
#
# 5. **Time Series Aggregation**:
#    - Plot total daily revenue (`OrderDate` vs. `TotalAmount`) using a line plot.
#    - Compute the monthly average quantity sold per category.
#
# > 💡 Use `.groupby()`, `.agg()`, `.pivot_table()`, and visualization functions where appropriate.

# %%
# Add an excercice to students

# %%
# 1
# Basic Exploration**:
# Display the first 5 rows.
sales_data = pd.read_csv('sales_data.csv')
sales_data.head(5)
# Out:
#    OrderID  CustomerID     Product     Category  Quantity   Price   OrderDate  \
# 0    25795        1921      Tablet  Electronics         2   62.49  2023-04-29
# 1    10860        1969      Tablet  Accessories         1  696.56  2023-05-01
# 2    86820        1601  Headphones  Electronics         2  983.76  2023-01-19
# 3    64886        1417     Charger  Electronics         1  242.98  2023-06-24
# 4    16265        1114      Laptop  Electronics         1  146.54  2023-05-22
#
#    Country
# 0       UK
# 1  Germany
# 2   France
# 3  Germany
# 4  Germany

# %%
sales_data.shape
# Out:
# (500, 8)

# %%
# Count missing values in each column.
sales_data.isnull().sum()
# Out:
# OrderID       0
# CustomerID    0
# Product       0
# Category      0
# Quantity      0
# Price         0
# OrderDate     0
# Country       0
# dtype: int64

# %%
# Print summary statistics for `Quantity` and `Price`.
sales_data[['Quantity', 'Price']].describe()
# Out:
#          Quantity      Price
# count  500.000000  500.00000
# mean     4.896000  507.91238
# std      2.567171  287.00474
# min      1.000000    8.20000
# 25%      3.000000  257.79500
# 50%      5.000000  517.38500
# 75%      7.000000  760.82250
# max      9.000000  998.36000

# %%
sales_data_quantity_price = sales_data[(sales_data['Quantity'] == 0) & (sales_data['Price'] == 0)]
sales_data_quantity_price
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, Product, Category, Quantity, Price, OrderDate, Country]
# Index: []

# %%
# 2
# Data Cleaning**:
# Remove rows where `Quantity` or `Price` is less than or equal to 0.
sales_data = sales_data[(sales_data['Quantity'] > 0) & (sales_data['Price'] > 0)]
sales_data.shape
# Out:
# (500, 8)

# %%
# Convert `OrderDate` to datetime format.
sales_data['OrderDate'] = pd.to_datetime(sales_data['OrderDate'])
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderID     500 non-null    int64
#  1   CustomerID  500 non-null    int64
#  2   Product     500 non-null    object
#  3   Category    500 non-null    object
#  4   Quantity    500 non-null    int64
#  5   Price       500 non-null    float64
#  6   OrderDate   500 non-null    datetime64[ns]
#  7   Country     500 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 31.4+ KB

# %%
# 3.
# Feature Engineering**:
# Create a new column `TotalAmount` = `Quantity` × `Price`.
sales_data['TotalAmount'] = sales_data['Quantity'] * sales_data['Price']
sales_data.head()
# Out:
#    OrderID  CustomerID     Product     Category  Quantity   Price  OrderDate  \
# 0    25795        1921      Tablet  Electronics         2   62.49 2023-04-29
# 1    10860        1969      Tablet  Accessories         1  696.56 2023-05-01
# 2    86820        1601  Headphones  Electronics         2  983.76 2023-01-19
# 3    64886        1417     Charger  Electronics         1  242.98 2023-06-24
# 4    16265        1114      Laptop  Electronics         1  146.54 2023-05-22
#
#    Country  TotalAmount
# 0       UK       124.98
# 1  Germany       696.56
# 2   France      1967.52
# 3  Germany       242.98
# 4  Germany       146.54

# %%
# Extract the `Month` and `DayOfWeek` from `OrderDate`.
sales_data['Month'] = sales_data['OrderDate'].dt.month
sales_data['DayOfWeek'] = sales_data['OrderDate'].dt.dayofweek
sales_data.head()
# Out:
#    OrderID  CustomerID     Product     Category  Quantity   Price  OrderDate  \
# 0    25795        1921      Tablet  Electronics         2   62.49 2023-04-29
# 1    10860        1969      Tablet  Accessories         1  696.56 2023-05-01
# 2    86820        1601  Headphones  Electronics         2  983.76 2023-01-19
# 3    64886        1417     Charger  Electronics         1  242.98 2023-06-24
# 4    16265        1114      Laptop  Electronics         1  146.54 2023-05-22
#
#    Country  TotalAmount  Month  DayOfWeek
# 0       UK       124.98      4          5
# 1  Germany       696.56      5          0
# 2   France      1967.52      1          3
# 3  Germany       242.98      6          5
# 4  Germany       146.54      5          0

# %%
# 4 
# Analysis:
# What is the total revenue per `Country`? (Sort descending)
total_revenue = sales_data.groupby('Country')['TotalAmount'].sum().sort_values(ascending=False)
total_revenue
# Out:
# Country
# Spain      279412.27
# USA        255293.26
# UK         240956.09
# Germany    237998.58
# France     229219.37
# Name: TotalAmount, dtype: float64

# %%
# What are the top 5 best-selling products by `Quantity`?
top_products = sales_data.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head(5)
top_products
# Out:
# Product
# Phone         552
# Charger       502
# Tablet        485
# Laptop        470
# Headphones    439
# Name: Quantity, dtype: int64

# %%
# How many unique customers are there in each `Country`?
unique_customers = sales_data.groupby('Country')['CustomerID'].nunique()
unique_customers
# Out:
# Country
# France      97
# Germany     95
# Spain       99
# UK          89
# USA        104
# Name: CustomerID, dtype: int64

# %%
# 5. 
# **Time Series Aggregation**:
# Plot total daily revenue (`OrderDate` vs. `TotalAmount`) using a line plot.
daily_revenue = sales_data.groupby('OrderDate')['TotalAmount'].sum()
daily_revenue.plot(title='Daily Revenue', figsize=(10, 4))
# Out:
# <Axes: title={'center': 'Daily Revenue'}, xlabel='OrderDate'>

# %%
# Compute the monthly average quantity sold per category.
monthly_avg_quantity = sales_data.groupby(['Category', 'Month'])['Quantity'].mean().unstack()
monthly_avg_quantity.plot(title='Monthly Average Quantity Sold per Category', figsize=(10, 4))
# Out:
# <Axes: title={'center': 'Monthly Average Quantity Sold per Category'}, xlabel='Category'>
